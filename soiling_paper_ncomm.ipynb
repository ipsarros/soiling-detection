# %% [markdown]
# # Changepoint detection and deviation detection
# Notebook containing experimental evaluation of soiling modelling methods.

# %%
import numpy as np
import os, sys
import math
from sklearn.linear_model import LinearRegression, Ridge, SGDRegressor, Lasso, ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['axes.facecolor']='w'
plt.rcParams['savefig.facecolor']='w'
# %matplotlib inline 
#from my_functions import *
from modules.preprocessing import *
from modules.statistics import *
from modules.io import *
from modules.learning import *
from scipy import stats
from ast import literal_eval

#from modules.experiments import *
import matplotlib.dates as mdates

# %% [markdown]
# ## Read data
# Read input time series. Manual washing dates are given as input.

# %%
def parse_csv(filename):
    df_meta = pd.read_csv(filename, nrows=1)
    df_temp = pd.read_csv(filename, sep='\n', header=None, names=["temp"])
    col_names = df_temp.temp.iloc[2].split(',')
    col_names.extend(['I-V Curve I Values', 'I-V Curve V Values'])
    rows = []
    num_r = df_temp.iloc[3:].shape[0]
    
    # handle columns
    for i in range(num_r):
        data = df_temp.temp.loc[3+i].split(',')
        N = int(data[41])
        rows.append(data[:42])
        rows[i].extend([np.array(data[42:42+N]), np.array(data[42+N:])])
    df = pd.DataFrame(columns=col_names, data=rows)
    
    # convert to datetime
    df.iloc[:, 0] = pd.to_datetime(df.iloc[:, 0], errors='coerce') 
    
    # convert to datetime.time (99:99 will be replaced with nan)
    df.iloc[:, 38] = pd.to_datetime(df.iloc[:, 38], format= '%H:%M', errors='coerce').dt.time
    df.iloc[:, 39] = pd.to_datetime(df.iloc[:, 39], format= '%H:%M', errors='coerce').dt.time
    
    # infer and convert to appropriate types for each column
    idx = [0, 38, 39, 42, 43]
    for j in range(1, df.shape[1]):
        if j in idx:
            continue
        df.iloc[:, j] = df.iloc[:, j].apply(literal_eval)
        
    # replace -9999 precipitation with nan
    idx1 = [x for x in list(range(df.shape[1])) if x not in idx]
    df.iloc[:, idx1] = df.iloc[:, idx1].replace(-9999, np.nan)
    
    return df_meta, df

# %%
#filename = '/data/data1/data-for-validating-models/Data For Validating Models/Cocoa/Cocoa_CIGS39017.csv'
#filename = '/data/data1/data-for-validating-models/Data For Validating Models/Cocoa/Cocoa_mSi0188.csv'
filename = '/data/data1/data-for-validating-models/Data For Validating Models/Eugene/Eugene_mSi0188.csv'
#filename = '/data/data1/data-for-validating-models/Data For Validating Models/Golden/Golden_mSi0251.csv'



#washing dates for Cocoa:
#dates_wash_start = pd.to_datetime(pd.Series(['2011-02-28 00:00:00', '2012-02-10 00:00:00']))
#dates_wash_stop = pd.to_datetime(pd.Series(['2011-03-01 00:00:00', '2012-02-11 00:00:00']))
#washing dates for Eugene: 
dates_wash_start = pd.to_datetime(pd.Series(['2013-03-11 00:00:00', '2013-07-10 00:00:00', '2013-08-14 00:00:00', '2013-08-21 00:00:00', '2013-08-26 00:00:00']))
dates_wash_stop = pd.to_datetime(pd.Series(['2013-03-12 00:00:00', '2013-07-11 00:00:00', '2013-08-15 00:00:00', '2013-08-22 00:00:00','2013-08-27 00:00:00']))
# #no washing dates needed for Golden
#dates_wash_start = pd.to_datetime(pd.Series(['2012-09-14 06:15:16']))
#dates_wash_stop = pd.to_datetime(pd.Series(['2012-09-14 06:15:16']))

# %%
df_meta, df = parse_csv(filename)

df = df.iloc[:, [0, 1, 3, 5, 7, 9, 11, 13, 22, 26, 27, 30, 33, 37]]

df.columns = ['timestamp', 'irradiance', 'mod_temp', 'Shortcircuitcurrent', 'power',
               'dcurrent','Voltageatmax',
               'Opencircuitvoltage', 'humidity', 'precipitation', 'dni', 'ghi', 'dhi', 'soiling_derate']

df = df.set_index('timestamp')
df = df.dropna()
df.head()
# Out:
#                      irradiance  mod_temp  Shortcircuitcurrent   power  \
# timestamp
# 2012-12-20 10:40:02        22.8       4.5               0.0688  0.8035
# 2012-12-20 10:45:02        31.0       4.6               0.0930  1.1519
# 2012-12-20 10:50:02        34.0       4.6               0.1017  1.2762
# 2012-12-20 10:55:02        29.2       4.6               0.0875  1.0675
# 2012-12-20 11:00:02        32.9       4.6               0.0979  1.2187
#
#                      dcurrent  Voltageatmax  Opencircuitvoltage  humidity  \
# timestamp
# 2012-12-20 10:40:02    0.0571       14.0619             18.7348      86.1
# 2012-12-20 10:45:02    0.0780       14.7685             19.3450      85.4
# 2012-12-20 10:50:02    0.0853       14.9553             19.5073      86.0
# 2012-12-20 10:55:02    0.0730       14.6176             19.2116      85.9
# 2012-12-20 11:00:02    0.0818       14.9050             19.4271      85.1
#
#                      precipitation  dni   ghi   dhi  soiling_derate
# timestamp
# 2012-12-20 10:40:02           18.8  0.0  28.0  28.3             1.0
# 2012-12-20 10:45:02           18.8  0.1  37.1  37.6             1.0
# 2012-12-20 10:50:02           18.8  0.1  41.2  41.8             1.0
# 2012-12-20 10:55:02           18.8  0.1  35.4  35.9             1.0
# 2012-12-20 11:00:02           18.9  0.1  40.5  41.1             1.0

# %% [markdown]
# ## Rescale
# Use MinMaxScaler to rescale all points to [0,1].

# %%
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)

# %%
df_scaled.describe()
# Out:
#          irradiance      mod_temp  Shortcircuitcurrent         power  \
# count  41670.000000  41670.000000         41670.000000  41670.000000
# mean       0.240040      0.488759             0.242939      0.229354
# std        0.236484      0.176826             0.238951      0.227015
# min        0.000000      0.000000             0.000000      0.000000
# 25%        0.045438      0.349922             0.047995      0.042359
# 50%        0.136528      0.461897             0.136770      0.128678
# 75%        0.419793      0.622084             0.420410      0.405196
# max        1.000000      1.000000             1.000000      1.000000
#
#            dcurrent  Voltageatmax  Opencircuitvoltage      humidity  \
# count  41670.000000  41670.000000        41670.000000  41670.000000
# mean       0.239599      0.552331            0.606761      0.623341
# std        0.238184      0.140278            0.144980      0.225187
# min        0.000000      0.000000            0.000000      0.000000
# 25%        0.045305      0.493751            0.539460      0.446250
# 50%        0.132569      0.587347            0.635596      0.653750
# 75%        0.417268      0.645686            0.702377      0.815000
# max        1.000000      1.000000            1.000000      1.000000
#
#        precipitation           dni           ghi           dhi  soiling_derate
# count   41670.000000  41670.000000  41670.000000  41670.000000    41670.000000
# mean        0.027583      0.339249      0.237523      0.129672        0.906683
# std         0.089349      0.391078      0.209455      0.107905        0.189237
# min         0.000000      0.000000      0.000000      0.000000        0.000000
# 25%         0.000000      0.004215      0.068020      0.056834        0.861111
# 50%         0.000000      0.026693      0.159569      0.089934        1.000000
# 75%         0.004184      0.792875      0.369035      0.169876        1.000000
# max         1.000000      1.000000      1.000000      1.000000        1.000000

# %% [markdown]
# ## Extract rains
# Use precipitation values to extract rains. Each rain corresponds to a maximal period of positive precipitation.

# %%
if df.precipitation.iloc[0]>0:
    precipitation = pd.concat([pd.Series({min(df.index)-pd.Timedelta('1s'): 0}),df.precipitation])
else:
    precipitation = df.precipitation

precipitation.index = pd.to_datetime(precipitation.index)
df_dates = pd.DataFrame(index = precipitation.index)
df_dates["rain_start"] = precipitation[(precipitation.shift(-1) > 0) & (precipitation == 0)] # compare current to next
df_dates["rain_stop"] = precipitation[(precipitation.shift(1) > 0) & (precipitation == 0)] # compare current to prev
dates_rain_start = pd.Series(df_dates.rain_start.index[df_dates.rain_start.notna()])
dates_rain_stop = pd.Series(df_dates.rain_stop.index[df_dates.rain_stop.notna()])

# %% [markdown]
# Number of rains:

# %%
dates_rain_stop.shape[0]
# Out:
# 69

# %% [markdown]
# ### Filter out light rains
# Any rain with maximum precipitation less than x is considered noise.

# %%
x = 0.1
ids = []
for idx in range(dates_rain_start.size):
    d1 = dates_rain_start[idx]
    d2 = dates_rain_stop[idx]
    if np.max(precipitation.loc[d1:d2]) >= x:
        ids.append(idx)
dates_rain_start_filtered = dates_rain_start[ids]
dates_rain_stop_filtered = dates_rain_stop[ids]

# %% [markdown]
# Number of remaining rains:

# %%
dates_rain_stop_filtered.shape[0]
# Out:
# 69

# %% [markdown]
# ### Regression model trained after manual cleanings
# Train a regression model on periods of w_train days after the manual washings of the panels.

# %%
w_train = 30
feats = ['irradiance', 'mod_temp']
target = 'power'
ref_points2 = pd.Index(dates_wash_stop)
model2, training_error2, validation_error2 = train_on_reference_points(df_scaled, w_train, ref_points2, feats, target)
validation_error2
# Out:
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.030
# MPE:-0.000
# R2: 0.998
# array([ 9.98135047e-01,  7.41077772e-03, -5.78349293e-05,  2.96083337e-02,
#        -2.31068310e-04,  1.01247060e+00])

# %%
df_scaled[target].head()
# Out:
# timestamp
# 2012-12-20 10:40:02    0.006365
# 2012-12-20 10:45:02    0.011958
# 2012-12-20 10:50:02    0.013954
# 2012-12-20 10:55:02    0.010603
# 2012-12-20 11:00:02    0.013031
# Name: power, dtype: float64

# %% [markdown]
# ## Detect changepoints

# %% [markdown]
# Two methods for detecting changepoints.
# Method 1. For each rain (or manual cleaning), we train and validate a regression model in the time period right before it, and we test it in the time period right after it. We then employ a score function which ranks preferably those rains with a small error before them and a large error after them.
# Method 2. We use the model trained on periods succeeding manual cleanings. For each rain (or manual cleaning), we measure the prediction error in the time period right before it, and the prediction error in the time period right after it. We then employ a score function which ranks preferably those rains with a large error before them and a small error after them.

# %% [markdown]
# ### Initialize parameters

# %%
w1 = 10  # window of days to train (before the rain)
w2 = 5 # window of days to validate (before the rain)
w3 = 10 # window of days to test (after the rain)

error_br_column = 5 #0=r_squared, 1=mae, 2=me, 3=mape, 4=mpe, 5=median error
error_ar_column = 5
thrsh = 1

# %%
errors_br1 = np.empty((dates_rain_start_filtered.size, 6))
errors_ar1 = np.empty((dates_rain_start_filtered.size, 6))
scores = np.empty((dates_rain_start_filtered.size))
indices = np.empty(len(scores), dtype=int)
error_names = {0: "r_squared", 1: "MAE", 2: "ME (true-pred)", 3: "MAPE", 4: "MPE (true-pred)", 5: "Median error"}

# %%
p_changepoints_start = (pd.Series(dates_rain_start_filtered.tolist() + dates_wash_start.tolist()).sort_values())
p_changepoints_stop = (pd.Series(dates_rain_stop_filtered.tolist() + dates_wash_stop.tolist()).sort_values())
p_changepoints_start = p_changepoints_start.reset_index()[0]
p_changepoints_stop = p_changepoints_stop.reset_index()[0]
type(p_changepoints_start)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Detection

# %%
#p_changepoints_start = (pd.Series(dates_rain_start_filtered.tolist() + dates_wash_start.tolist()).sort_values())
#p_changepoints_stop = (pd.Series(dates_rain_stop_filtered.tolist() + dates_wash_stop.tolist()).sort_values())
target = 'power'
feats = ['irradiance', 'mod_temp']
error_name_br = error_names[error_br_column] 
error_name_ar = error_names[error_ar_column]

#compute errors using one model per rain
errors_br1, errors_ar1, errors_all1 = calc_changepoints_many_models(df_scaled, p_changepoints_start, p_changepoints_stop, target, feats, w1, w2, w3 )
errors_br2, errors_ar2, errors_all2 = calc_changepoints_one_model(df_scaled, p_changepoints_start, p_changepoints_stop, model2, target, feats, 5, 10)#### 5, 10

#set threshold on MAPE error before rain
mask1 = (errors_br1[:,3]<= 0.05)
mask2 = (errors_ar2[:,3]<= 0.05)

#compute scores for the remaining
scores1 = -(errors_br1[:, error_br_column]-errors_ar1[:, error_ar_column])/np.abs(errors_br1[:, error_ar_column])

#scores for ratios:
scores_ratio1 = np.abs(errors_ar1[:, error_ar_column])/np.abs(errors_br1[:, error_ar_column])
scores1 = errors_all1

scores1[(~mask1)] = np.finfo('d').min

scores2 = -(errors_br2[:, error_br_column]-errors_ar2[:, error_ar_column])/np.abs(errors_ar2[:, error_ar_column])
#scores for ratios:
scores_ratio2 = np.abs(errors_br2[:, error_br_column])/np.abs(errors_ar2[:, error_ar_column])
scores2 = errors_all2
scores2[(~mask2)] = np.finfo('d').min


#print(np.sign(scores1)*np.sign(scores2))


#sort
indices1 = np.argsort(-scores1)
indices2 = np.argsort(-scores2)

#compute final output
precip = df.precipitation
df_events_output1 = pd.DataFrame(output_changepoints(scores1, indices1, p_changepoints_start, p_changepoints_stop, errors_br1[:, error_br_column], errors_ar1[:, error_ar_column], error_name_br, error_name_ar, precip))
df_events_output2 = pd.DataFrame(output_changepoints(scores2, indices2, p_changepoints_start, p_changepoints_stop, errors_br2[:, error_br_column], errors_ar2[:, error_ar_column], error_name_br, error_name_ar, precip))

# effective changepoints = the ones with score at least thrsh  
thrsh = np.quantile(df_events_output1['Score'].values, 0.9)
mask1 = (df_events_output1['Score']>thrsh)

thrsh = np.quantile(df_events_output2['Score'].values, 0.9)
mask2 = (df_events_output2['Score']>thrsh)

effective_cp1 = df_events_output1[mask1]["id"].values 
effective_cp2 = df_events_output2[mask2]["id"].values 

print(f'Number of "effective" changepoints using Method 1: {len(set(effective_cp1))}') 
print(f'Number of "effective" changepoints using Method 2: {len(set(effective_cp2))}')
# Out:
# Either the training set is empty or the test set is empty
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Number of "effective" changepoints using Method 1: 8
# Number of "effective" changepoints using Method 2: 8

# %% [markdown]
# ### Train model after changepoints computed by Method 1

# %%
ref_points = pd.Index(pd.Series(p_changepoints_stop.iloc[list(effective_cp1)]))
model1, training_error, validation_error = train_on_reference_points(df_scaled, w_train, ref_points, feats, target)
validation_error
# Out:
# Training Metrics:
# MAE:0.007
# ME(true-pred):0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):0.000
# MAPE:0.027
# MPE:0.000
# R2: 0.998
# array([9.98259115e-01, 6.94995963e-03, 9.78267402e-06, 2.73039815e-02,
#        3.84327341e-05, 1.00623527e+00])

# %% [markdown]
# ### Train model after changepoints computed by Method 2

# %%
ref_points = pd.Index(pd.Series(p_changepoints_stop.iloc[list(effective_cp2)]))
model3, training_error, validation_error = train_on_reference_points(df_scaled, w_train, ref_points, feats, target)
validation_error
# Out:
# Training Metrics:
# MAE:0.008
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.028
# MPE:0.000
# R2: 0.998
# array([9.98057311e-01, 7.64388865e-03, 1.01842827e-04, 2.81922867e-02,
#        3.75618001e-04, 1.00408686e+00])

# %% [markdown]
# ### Compare three models

# %%
y_pred1 = predict(df_scaled, model1, feats, target)
y_pred2 = predict(df_scaled, model2, feats, target)
y_pred3 = predict(df_scaled, model3, feats, target)
derate1 = np.maximum(np.minimum(df_scaled.power/y_pred1,1),0.0)
print(type(derate1))
derate1 = derate1.rolling('1D', min_periods=1,center = True).median()
derate2 = np.maximum(np.minimum(df_scaled.power/y_pred2,1),0.0)
derate2 = derate2.rolling('1D', min_periods=1, center = True).median()
derate3 = np.maximum(np.minimum(df_scaled.power/y_pred3,1),0.0)
derate3 = derate3.rolling('1D', min_periods=1, center = True).median()
ax1 = df['soiling_derate'].plot(figsize=(12,8), color = 'goldenrod',label = 'soiling ratio')
ax1.plot(derate1, color = 'blue', alpha = 0.3, label = 'model1')
ax1.plot(derate2, color = 'red', alpha = 0.4, label = 'model2')
ax1.plot(derate3, color = 'green', alpha = 0.5, label = 'model3')
plt.legend()
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Modelling soiling ratio

# %%
sdd = df.soiling_derate.resample('D').mean()
sdd = sdd.fillna(method='ffill').copy()
sdd = sdd.fillna(method='bfill').copy()

# %% [markdown]
# ### SRR Performance index

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pvlib
import rdtools
import itertools
from sklearn.metrics import mean_squared_error as mse


def run_rdtools_pipeline(df, time_filter, irradiance_filter, rd_filter, percentile_normal, insolation_normal):

    df_1 = df.copy()




    df_1.columns = ['poa', 'Tcell', 'Shortcircuitcurrent', 'power',
                   'dcurrent','Voltageatmax',
                   'Opencircuitvoltage', 'humidity', 'precipitation', 'dni', 'ghi', 'dhi', 'soiling_derate']
    df_1.index = pd.DatetimeIndex(df_1.index)
    df_1 = df_1.dropna()
    if time_filter:
        start = '12:00'
        end = '14:00'
        df_test = df_1.between_time(start, end)
    else: 
        df_test = df_1
    if irradiance_filter:    
    # 0 is the index of irradiance after setting the datetimeindex
        df_test = filter_col(df_test, 0, less_than=500, bigger_than=None)
    else: 
        df_test = df_1

    df_test = df_test.dropna()
    df_1 = df_test
    meta = {"gamma_pdc": -0.005,
        "power_dc_rated": 44.82#45.91#45.8 #45.91,#1000.0,
       }
    # There is some missing data, but we can infer the frequency from
    # the first several data points
    freq = pd.infer_freq(df_1.index[:10])

    # Then set the frequency of the dataframe.
    # It is recommended not to up- or downsample at this step
    # but rather to use interpolate to regularize the time series
    # to its dominant or underlying frequency. Interpolate is not
    # generally recommended for downsampling in this application.
    df_1 = rdtools.interpolate(df_1, df_1.index)
    
    # Calculate the expected power with a simple PVWatts DC model
    modeled_power = pvlib.pvsystem.pvwatts_dc(df_1['poa'], df_1['Tcell'], meta['power_dc_rated'],
                               meta['gamma_pdc'], 25)
    modeled_power_t = pvlib.pvsystem.pvwatts_dc(df_test['poa'], df_test['Tcell'], meta['power_dc_rated'],
                               meta['gamma_pdc'], 25)

   
    #added this:
    ##################################
    df_1 = df_1.resample('5T').median()
    #needed for golden:
    #df_1 = df_1.interpolate()
    ##################################

    normalized, insolation = rdtools.normalize_with_expected_power(df_1['power'],
                                                                   modeled_power,
                                                                   df_1['poa'])

    
    
    df_1['normalized'] = normalized
    df_1['insolation'] = insolation
    
    if rd_filter:
        normalized_mask = rdtools.normalized_filter(df_1['normalized'])
        poa_mask = rdtools.poa_filter(df_1['poa'])
        tcell_mask = rdtools.tcell_filter(df_1['Tcell'])
        clip_mask = rdtools.clip_filter(df_1['power'], 'quantile', quantile=0.98)
        #clip_mask = rdtools.clip_filter(df_1['power'], 'xgboost')
        #clip_mask = rdtools.clip_filter(df_1['power'], 'logic')
        filtered = df_1[normalized_mask & poa_mask & tcell_mask & clip_mask]
    else: 
        filtered = df_1
    filtered = filtered[['power','insolation', 'normalized']]
   
    if insolation_normal:
        daily = rdtools.aggregation_insol(filtered.normalized, filtered.insolation,frequency = 'D')
    else:
        daily = filtered.power.resample('D').sum() / modeled_power.resample('D').sum()
    
    if percentile_normal and len(daily[daily > 0])>0:
        daily = daily / np.percentile(daily[daily > 0], 95)
        
    daily = daily.fillna(method='ffill', limit=14).copy()

    return daily, filtered


l = [False, True]

fig, ax = plt.subplots()
rmses = [] 
daily_list = []
masks = []    
daily, filtered = run_rdtools_pipeline(df, time_filter=True, irradiance_filter=True, rd_filter=True, percentile_normal=True, insolation_normal=True)
daily_smoothed = daily.reindex(sdd.index).rolling(1, center=True).median()

daily_smoothed = daily_smoothed.fillna(method='ffill').copy()
daily_smoothed = daily_smoothed.fillna(method='bfill').copy()
daily_smoothed_final = np.maximum(np.minimum(daily_smoothed,1),0.0)
ax.plot(sdd.index, daily_smoothed, alpha = 0.5) #, label = 'rdtools-normalized')
ax.plot(sdd.index, daily_smoothed_final, alpha = 0.5, label = 'final') #, label = 'rdtools-normalized')
ax.plot(sdd, color = 'goldenrod', label = 'groundtruth')
ax.set_ylim(0.94,1.05)
ax.legend()
# Out:
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (15.17%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.48%) exceeded threshold
#   warnings.warn("Fraction of excluded data "

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(16,14))
#plt.suptitle(f'Changepoint Detection Methods')
axes = axes.ravel()


ax2 = axes[0]
ax2.set_title('Model trained after manual cleanings')
y_pred2 = predict(df_scaled, model2, feats, target)
derate2 = np.maximum(np.minimum(df_scaled.power/y_pred2,1),0.0)
derate2 = derate2.rolling('1D', min_periods=1, center = True).median()
ax2 = df['soiling_derate'].plot(ax = ax2, color = 'goldenrod',label = 'soiling derate')
ax2.plot(derate2, color = 'blue', alpha = 0.3, label = 'modelled soiling ratio')
ax2.xaxis.set_visible(False)
ax2.legend()

ax1 = axes[1]
ax1.set_title('Model trained after cleaning events obtained by Method 1')
y_pred1 = predict(df_scaled, model1, feats, target)
derate1 = np.maximum(np.minimum(df_scaled.power/y_pred1,1),0.0)
derate1 = derate1.rolling('1D', min_periods=1,center = True).median()
ax1 = df['soiling_derate'].plot(ax = ax1, color = 'goldenrod',label = 'soiling derate')
ax1.plot(derate1, color = 'blue', alpha = 0.3, label = 'modelled soiling ratio')
ax1.xaxis.set_visible(False)
ax1.legend()


ax3 = axes[2]
ax3.set_title('Model trained after cleaning events obtained by Method 2')
y_pred3 = predict(df_scaled, model3, feats, target)
derate3 = np.maximum(np.minimum(df_scaled.power/y_pred3,1),0.0)
derate3 = derate3.rolling('1D', min_periods=1, center = True).median()
ax3 = df['soiling_derate'].plot(ax = ax3, color = 'goldenrod',label = 'soiling derate')
ax3.plot(derate3, color = 'blue', alpha = 0.3, label = 'modelled soiling ratio')
ax3.xaxis.set_visible(False)
ax3.legend()

ax4 = axes[3]
ax4.set_title('Performance Metric (SRR)')
ax4 = df['soiling_derate'].plot(ax = ax4, color = 'goldenrod',label = 'soiling derate')
#ax4.plot(p_index, color = 'black', alpha = 0.3, label = 'Perf. metric (SRR)')
ax4.plot(daily_smoothed_final, color = 'black', alpha = 0.3, label = 'Perf. metric (SRR)')

ax4.legend()
plt.show()

# %%
gt_daily = sdd

derate1_daily = derate1.resample('1D').median()
derate1_daily = derate1_daily.reindex(gt_daily.index).interpolate()

derate2_daily = derate2.resample('1D').median()
derate2_daily = derate2_daily.reindex(gt_daily.index).interpolate()

derate3_daily = derate3.resample('1D').median()
derate3_daily = derate3_daily.reindex(gt_daily.index).interpolate()

# %%
len(derate3_daily[~derate3_daily.index.duplicated(keep='first')])
# Out:
# 397

# %%
#Calculate RMSE for each model and srr
from sklearn.metrics import mean_squared_error as mse
gt = df['soiling_derate']
print(gt.shape)
rmse1 = mse(gt_daily, derate1_daily, squared=False)
rmse2 = mse(gt_daily, derate2_daily, squared=False)
rmse3 = mse(gt_daily, derate3_daily, squared=False)
rmse_srr = mse(gt_daily, daily_smoothed_final, squared=False)
print(f'RMSE derate1 = ', rmse1)
print(f'RMSE derate2 = ', rmse2)
print(f'RMSE derate3 = ', rmse3)
print(f'RMSE     srr = ', rmse_srr)
# Out:
# (41670,)
# RMSE derate1 =  0.007432672087941156
# RMSE derate2 =  0.00581566810520564
# RMSE derate3 =  0.005001817257477365
# RMSE     srr =  0.019076224644053546

# %% [markdown]
# ## Plot changepoints

# %%
daily_insolation = filtered['insolation'].resample('D').sum()
daily_prec = precipitation.resample("1D").sum().dropna()
daily, filtered = run_rdtools_pipeline(df, time_filter=True, irradiance_filter=True, rd_filter=True, percentile_normal=True, insolation_normal=True)

x = np.max(daily_prec)
for i in range(len(dates_wash_start)):
    daily_prec[dates_wash_start[i]:dates_wash_stop[i]] = x
    print(daily_prec[dates_wash_start[i]:dates_wash_stop[i]])
    
# Perform the SRR calculation
from rdtools.soiling import soiling_srr
cl = 68.2
#sr, sr_ci, soiling_info = soiling_srr(daily, daily_insolation, precipitation_daily= daily_prec, clean_criterion = 'precip_and_shift',
#                                      min_interval_length = 7,confidence_level=cl, clean_threshold= 'infer', method = 'half_norm_clean' ,  precip_threshold=0.1)
sr, sr_ci, soiling_info = soiling_srr(daily, daily_insolation, precipitation_daily= daily_prec, clean_criterion = 'precip_and_shift',
                                      min_interval_length = 7,confidence_level=cl, clean_threshold = 'infer', method = 'perfect_clean' ,  precip_threshold=0.1)
# Out:
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (15.17%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.48%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/soiling.py:14: UserWarning: The soiling module is currently experimental. The API, results, and default behaviors may change in future releases (including MINOR and PATCH releases) as the code matures.
#   warnings.warn(
# 2013-03-11    1477.2
# 2013-03-12    1477.2
# Freq: D, dtype: float64
# 2013-07-10    1477.2
# 2013-07-11    1477.2
# Freq: D, dtype: float64
# 2013-08-14    1477.2
# 2013-08-15    1477.2
# Freq: D, dtype: float64
# 2013-08-21    1477.2
# 2013-08-22    1477.2
# Freq: D, dtype: float64
# 2013-08-26    1477.2
# 2013-08-27    1477.2
# Freq: D, dtype: float64

# %%
df_cp = soiling_info['soiling_interval_summary']
starts_of_interv = df_cp.start

# %%
dates_changepoints1 = pd.DatetimeIndex(p_changepoints_stop.iloc[list(effective_cp1)])
dates_changepoints2 = pd.DatetimeIndex(p_changepoints_stop.iloc[list(effective_cp2)])

# %% [markdown]
# #### Method 1

# %%
ymin = min(df['soiling_derate'].values)
ax1 = df['soiling_derate'].plot( color = 'goldenrod', label='soiling derate',figsize=(12,8))
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.vlines(x=dates_changepoints1, ymin=ymin, ymax=1, colors='blue', alpha = 0.6,ls='-', lw= 2, label='cleaning events 1')

ax1.vlines(x=starts_of_interv, ymin=ymin, ymax=1, colors='red', alpha = 1,ls='--', lw= 2, label='SRR')
ax1.annotate('', xy=(0.339, 1.05), xycoords='axes fraction', xytext=(0.339, 1), arrowprops=dict(arrowstyle="<-", color='green',lw =3))
b=0.92
#ax1.annotate('', xy=(b, 1.05), xycoords='axes fraction', xytext=(b, 1), arrowprops=dict(arrowstyle="<-", color='green',lw =3))

ax1.legend()
plt.show()

# %% [markdown]
# #### Method 2

# %%
ymin = min(df['soiling_derate'].values)
ax2 = df['soiling_derate'].plot( color = 'goldenrod', label='soiling derate', figsize=(12,8))
ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax2.vlines(x=dates_changepoints2, ymin=ymin, ymax=1, colors='blue', alpha = 0.6,ls='-', lw= 2, label='cleaning events 2')

ax2.vlines(x=starts_of_interv, ymin=ymin, ymax=1, colors='red', alpha = 1,ls='--', lw= 2, label='SRR')
ax2.annotate('', xy=(0.339, 1.05), xycoords='axes fraction', xytext=(0.339, 1), arrowprops=dict(arrowstyle="<-", color='green',lw =3))
b=0.92
#ax2.annotate('', xy=(b, 1.05), xycoords='axes fraction', xytext=(b, 1), arrowprops=dict(arrowstyle="<-", color='green',lw =3))

ax2.legend()
plt.show()

# %% [markdown]
# ## Incremental detection
# ### Preliminaries

# %%
pot_changepoints_start = pd.Index(pd.Series(dates_rain_start_filtered.tolist() + dates_wash_start.tolist()).sort_values())
pot_changepoints_stop = pd.Index(pd.Series(dates_rain_stop_filtered.tolist() + dates_wash_stop.tolist()).sort_values())
t1 = min(df_scaled.index)
t2 = t1 = t1+pd.Timedelta(days=30)
i1 = pot_changepoints_start.get_loc(t1, method='backfill')
i2 = pot_changepoints_stop.get_loc(t2, method='pad')

# %%
target = 'power'
feats = ['irradiance', 'mod_temp']
def compute_changepoints1(df_scaled, p_changepoints_start, p_changepoints_stop, target, feats): 
    
    #compute errors using one model per rain
    errors_br1, errors_ar1, errors_all1 = calc_changepoints_many_models(df_scaled, p_changepoints_start, p_changepoints_stop, target, feats, 10, 5, 10 )
    
    #set threshold on MAPE error before rain
    mask1 = (errors_br1[:,3]<= 0.05)

    scores1 = errors_all1

    scores1[(~mask1)] = np.finfo('d').min

    indices1 = np.argsort(-scores1)
    #compute final output
    precip = df.precipitation
    df_events_output1 = pd.DataFrame(output_changepoints(scores1, indices1, p_changepoints_start, p_changepoints_stop, errors_br1[:, error_br_column], errors_ar1[:, error_ar_column], error_name_br, error_name_ar, precip))
    
    # effective changepoints = the ones with score at least thrsh  
    thrsh = np.quantile(df_events_output1['Score'].values, 0.9)
    mask1 = (df_events_output1['Score']>thrsh)
    effective_cp1 = df_events_output1[mask1]["id"].values 
    return effective_cp1
    
    
def compute_changepoints2(df_scaled, model2, p_changepoints_start, p_changepoints_stop, target, feats): 
    #compute errors using one model per rain
    errors_br2, errors_ar2, errors_all2 = calc_changepoints_one_model(df_scaled, p_changepoints_start, p_changepoints_stop, model2, target, feats, 5, 10)#### 5, 10
    
    mask2 = (errors_br2[:,3]<= 0.05)

    scores2 = errors_all2
    scores2[(~mask2)] = np.finfo('d').min
    indices2 = np.argsort(-scores2)

    #compute final output
    precip = df.precipitation
    df_events_output2 = pd.DataFrame(output_changepoints(scores2, indices2, p_changepoints_start, p_changepoints_stop, errors_br2[:, error_br_column], errors_ar2[:, error_ar_column], error_name_br, error_name_ar, precip))

    thrsh = np.quantile(df_events_output2['Score'].values, 0.9)
    mask2 = (df_events_output2['Score']>thrsh)
    effective_cp2 = df_events_output2[mask2]["id"].values 
    return effective_cp2

# %%
pot_changepoints_start = pd.DatetimeIndex(pd.Series(dates_rain_start_filtered.tolist() + dates_wash_start.tolist()).sort_values())
type(pot_changepoints_start)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
t = pd.Timestamp('2013-02-11 16:55:02')
i = pot_changepoints_start.get_loc(t, method = 'bfill')
pot_changepoints_start[:i]
# Out:
# DatetimeIndex(['2012-12-20 10:40:01', '2013-01-04 16:30:02',
#                '2013-01-08 16:25:02', '2013-01-23 11:30:02',
#                '2013-01-24 16:10:02', '2013-02-04 16:55:02'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Experiment

# %%
#dates_changepoints1 = pd.DatetimeIndex(p_changepoints_stop.iloc[list(effective_cp1)]).sort_values()
#dates_changepoints2 = pd.DatetimeIndex(p_changepoints_stop.iloc[list(effective_cp2)]).sort_values()
washing_dates = pd.Index(dates_wash_stop).sort_values()
pot_changepoints_start = pd.Index(pd.Series(dates_rain_start_filtered.tolist() + dates_wash_start.tolist()).sort_values())
pot_changepoints_stop = pd.Index(pd.Series(dates_rain_stop_filtered.tolist() + dates_wash_stop.tolist()).sort_values())



#number of days
step = 30
w_train = 30
feats = ['irradiance', 'mod_temp']
target = 'power'
t = min(df_scaled.index)
models1 = {}
models2 = {}
models3 = {}
error_list = {}
derate_daily_pred_list1 = []
derate_daily_pred_list2 = []
derate_daily_pred_list3 = []
while t <= max(df_scaled.index):
    t = t + pd.Timedelta(days=step)
    t_next = t + pd.Timedelta(days=step)
    ##### debug: update reference points on each iteration
    
    if len(df_scaled[:t])>0 and len(df_scaled[t:])>0: 
        #train after manual cleanings
        j = pot_changepoints_stop.get_loc(t, method = 'ffill')##########
        print(f'j = {pot_changepoints_stop[j]} and t = {t}')
        try:
            i = washing_dates.get_loc(t, method = 'ffill')#############
            models2[t], training_error, validation_error = train_on_reference_points(df_scaled[:t], w_train, washing_dates[0:(i+1)], feats, target)
            print('models are computed')
            #model trained after changepoints2
            y_pred2 = predict(df_scaled[t:t_next], models2[t], feats, target)
            derate = np.maximum(np.minimum(df_scaled[t:t_next].power/y_pred2,1),0.0)
            derate = derate.rolling('1D', min_periods=1, center = False).median()
            derate_daily2 = derate.resample('1D').median().dropna()
            #derate_daily2 = derate_daily.reindex(gt_daily[t:].index).interpolate()
            #rmse2 = mse(gt_daily[derate_daily2.index], derate_daily2, squared=False)
            derate_daily_pred_list2.append(derate_daily2)
            print(f'model after cleaning {t}')
            
            #####
            effective_cp2 = compute_changepoints2(df_scaled[:t], models2[t], pd.Series(pot_changepoints_start[:(j+1)]), pd.Series(pot_changepoints_stop[:(j+1)]), target, feats)
            dates_changepoints2 = pd.DatetimeIndex(p_changepoints_stop.iloc[list(effective_cp2)]).sort_values()
            models3[t], training_error, validation_error = train_on_reference_points(df_scaled[:t], w_train, dates_changepoints2, feats, target)
            #model trained after manual cleanings
            y_pred3 = predict(df_scaled[t:t_next], models3[t], feats, target)
            derate = np.maximum(np.minimum(df_scaled[t:t_next].power/y_pred3,1),0.0)
            derate = derate.rolling('1D', min_periods=1, center = False).median()
            derate_daily3 = derate.resample('1D').median().dropna()
            #derate_daily3 = derate_daily.reindex(gt_daily[t:].index).interpolate()
            #rmse3 = mse(gt_daily[derate_daily3.index], derate_daily3, squared=False)
            derate_daily_pred_list3.append(derate_daily3)
        except Exception as e:
            derate_daily2 = np.nan
            derate_daily3 = np.nan

            #rmse2 = np.nan
        
        dates_changepoints1 = compute_changepoints1(df_scaled[:t], pd.Series(pot_changepoints_start[:(j+1)]), pd.Series(pot_changepoints_stop[:(j+1)]), target, feats)
        print(len(dates_changepoints1))
        try:
            effective_cp1 = compute_changepoints1(df_scaled[:t], pd.Series(pot_changepoints_start[:(j+1)]), pd.Series(pot_changepoints_stop[:(j+1)]), target, feats)
            dates_changepoints1 = pd.DatetimeIndex(p_changepoints_stop.iloc[list(effective_cp1)]).sort_values()

            models1[t], training_error, validation_error = train_on_reference_points(df_scaled[:t], w_train, dates_changepoints1, feats, target)
            #model trained after changepoints1
            y_pred1 = predict(df_scaled[t:t_next], models1[t], feats, target)
            derate = np.maximum(np.minimum(df_scaled[t:t_next].power/y_pred1,1),0.0)
            derate = derate.rolling('1D', min_periods=1, center = False).median()
            derate_daily1 = derate.resample('1D').median().dropna()
            #rmse1 = mse(gt_daily[derate_daily1.index], derate_daily1, squared=False)
            derate_daily_pred_list1.append(derate_daily1) 
            
        except Exception as e:
            derate_daily1 = np.nan
            #rmse1 = np.nan    
        #dates_changepoints2 = compute_changepoints2(df_scaled[:t], models2[t], pd.Series(pot_changepoints_start[:j]), pd.Series(pot_changepoints_stop[:j]), target, feats)
# Out:
# j = 2013-01-13 08:45:02 and t = 2013-01-19 10:40:02
# Either the training set is empty or the test set is empty
# 1
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.002
# ME(true-pred):0.000
# MAPE:0.012
# R2: 1.000
#
# Validation Metrics:
# MAE:0.002
# ME(true-pred):0.000
# MAPE:0.012
# MPE:0.002
# R2: 1.000
#
# j = 2013-02-18 07:30:02 and t = 2013-02-18 10:40:02
# Either the training set is empty or the test set is empty
# 1
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.000
# ME(true-pred):0.000
# MAPE:0.006
# R2: 1.000
#
# Validation Metrics:
# MAE:0.001
# ME(true-pred):0.000
# MAPE:0.010
# MPE:0.001
# R2: 1.000
#
# j = 2013-03-17 06:40:02 and t = 2013-03-20 10:40:02
# Training Metrics:
# MAE:0.003
# ME(true-pred):0.000
# MAPE:0.017
# R2: 0.999
#
# Validation Metrics:
# MAE:0.003
# ME(true-pred):0.000
# MAPE:0.015
# MPE:0.001
# R2: 0.999
#
# models are computed
# model after cleaning 2013-03-20 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.003
# ME(true-pred):0.000
# MAPE:0.019
# R2: 0.999
#
# Validation Metrics:
# MAE:0.003
# ME(true-pred):-0.000
# MAPE:0.019
# MPE:-0.000
# R2: 0.999
#
# Either the training set is empty or the test set is empty
# 2
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.003
# ME(true-pred):-0.000
# MAPE:0.017
# R2: 0.999
#
# Validation Metrics:
# MAE:0.003
# ME(true-pred):-0.000
# MAPE:0.018
# MPE:-0.000
# R2: 0.999
#
# j = 2013-04-17 05:55:02 and t = 2013-04-19 10:40:02
# Training Metrics:
# MAE:0.004
# ME(true-pred):0.000
# MAPE:0.020
# R2: 0.999
#
# Validation Metrics:
# MAE:0.004
# ME(true-pred):0.000
# MAPE:0.020
# MPE:0.001
# R2: 0.999
#
# models are computed
# model after cleaning 2013-04-19 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.003
# ME(true-pred):-0.000
# MAPE:0.019
# R2: 0.999
#
# Validation Metrics:
# MAE:0.003
# ME(true-pred):-0.000
# MAPE:0.019
# MPE:-0.001
# R2: 0.999
#
# Either the training set is empty or the test set is empty
# 3
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.004
# ME(true-pred):-0.000
# MAPE:0.021
# R2: 0.999
#
# Validation Metrics:
# MAE:0.004
# ME(true-pred):-0.000
# MAPE:0.022
# MPE:-0.001
# R2: 0.999
#
# j = 2013-05-17 05:30:02 and t = 2013-05-19 10:40:02
# Training Metrics:
# MAE:0.004
# ME(true-pred):0.000
# MAPE:0.020
# R2: 0.999
#
# Validation Metrics:
# MAE:0.004
# ME(true-pred):0.000
# MAPE:0.020
# MPE:0.001
# R2: 0.999
#
# models are computed
# model after cleaning 2013-05-19 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.003
# ME(true-pred):0.000
# MAPE:0.020
# R2: 0.999
#
# Validation Metrics:
# MAE:0.003
# ME(true-pred):-0.000
# MAPE:0.019
# MPE:-0.000
# R2: 0.999
#
# Either the training set is empty or the test set is empty
# 3
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.003
# ME(true-pred):-0.000
# MAPE:0.018
# R2: 0.999
#
# Validation Metrics:
# MAE:0.004
# ME(true-pred):-0.000
# MAPE:0.019
# MPE:-0.001
# R2: 0.999
#
# j = 2013-06-14 05:30:02 and t = 2013-06-18 10:40:02
# Training Metrics:
# MAE:0.004
# ME(true-pred):0.000
# MAPE:0.020
# R2: 0.999
#
# Validation Metrics:
# MAE:0.004
# ME(true-pred):0.000
# MAPE:0.020
# MPE:0.001
# R2: 0.999
#
# models are computed
# model after cleaning 2013-06-18 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.005
# ME(true-pred):-0.000
# MAPE:0.026
# R2: 0.999
#
# Validation Metrics:
# MAE:0.006
# ME(true-pred):-0.000
# MAPE:0.028
# MPE:-0.001
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 4
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.006
# ME(true-pred):0.000
# MAPE:0.027
# R2: 0.998
#
# Validation Metrics:
# MAE:0.006
# ME(true-pred):-0.000
# MAPE:0.028
# MPE:-0.001
# R2: 0.998
#
# j = 2013-07-11 00:00:00 and t = 2013-07-18 10:40:02
# Training Metrics:
# MAE:0.006
# ME(true-pred):0.000
# MAPE:0.026
# R2: 0.998
#
# Validation Metrics:
# MAE:0.006
# ME(true-pred):0.000
# MAPE:0.026
# MPE:0.002
# R2: 0.998
#
# models are computed
# model after cleaning 2013-07-18 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.027
# MPE:-0.000
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 4
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# MPE:-0.001
# R2: 0.998
#
# j = 2013-08-15 00:00:00 and t = 2013-08-17 10:40:02
# Training Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.030
# R2: 0.998
#
# Validation Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.031
# MPE:0.000
# R2: 0.998
#
# models are computed
# model after cleaning 2013-08-17 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.007
# ME(true-pred):0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# MPE:-0.000
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 5
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.008
# ME(true-pred):-0.000
# MAPE:0.028
# MPE:-0.000
# R2: 0.998
#
# j = 2013-09-07 06:20:02 and t = 2013-09-16 10:40:02
# Training Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.030
# R2: 0.998
#
# Validation Metrics:
# MAE:0.008
# ME(true-pred):-0.000
# MAPE:0.030
# MPE:-0.000
# R2: 0.998
#
# models are computed
# model after cleaning 2013-09-16 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.027
# MPE:-0.000
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 5
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.027
# MPE:-0.000
# R2: 0.998
#
# j = 2013-10-09 07:25:02 and t = 2013-10-16 10:40:02
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.030
# MPE:-0.000
# R2: 0.998
#
# models are computed
# model after cleaning 2013-10-16 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.008
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.029
# MPE:0.000
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 6
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# MPE:-0.000
# R2: 0.998
#
# j = 2013-11-13 08:10:02 and t = 2013-11-15 10:40:02
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.030
# MPE:-0.000
# R2: 0.998
#
# models are computed
# model after cleaning 2013-11-15 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.008
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.028
# MPE:0.000
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 7
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):0.000
# MAPE:0.027
# MPE:0.000
# R2: 0.998
#
# j = 2013-12-03 08:00:02 and t = 2013-12-15 10:40:02
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.030
# MPE:-0.000
# R2: 0.998
#
# models are computed
# model after cleaning 2013-12-15 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.008
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.008
# ME(true-pred):0.000
# MAPE:0.028
# MPE:0.000
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 7
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):0.000
# MAPE:0.027
# MPE:0.000
# R2: 0.998
#
# j = 2014-01-13 08:25:02 and t = 2014-01-14 10:40:02
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.030
# MPE:-0.000
# R2: 0.998
#
# models are computed
# model after cleaning 2014-01-14 10:40:02
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
# Training Metrics:
# MAE:0.008
# ME(true-pred):-0.000
# MAPE:0.029
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):0.000
# MAPE:0.029
# MPE:0.000
# R2: 0.998
#
# Either the training set is empty or the test set is empty
# 8
# Either the training set is empty or the test set is empty
# Training Metrics:
# MAE:0.007
# ME(true-pred):-0.000
# MAPE:0.028
# R2: 0.998
#
# Validation Metrics:
# MAE:0.007
# ME(true-pred):0.000
# MAPE:0.027
# MPE:0.000
# R2: 0.998

# %%
derate_daily_srr_list = []            
#srr        
step = 1
t = min(df.index) + pd.Timedelta(days=3)
while t <= max(df.index):      
    #must make changes here: filtering accesses whole time series
    daily, filtered = run_rdtools_pipeline(df[:t], time_filter=True, irradiance_filter=True, rd_filter=True, percentile_normal=True, insolation_normal=True)
    daily_smoothed = daily.reindex(sdd[:t].index).rolling(1, center=False).median()
    daily_smoothed = daily_smoothed.fillna(method='ffill').copy()
    daily_smoothed = daily_smoothed.fillna(method='bfill').copy()
    daily_smoothed_final = np.maximum(np.minimum(daily_smoothed,1),0.0)
    
    derate_daily_srr_list.append(daily_smoothed_final.tail(1))
    t = t + pd.Timedelta(days=step)
# Out:
# Filter Complete
# Filter Complete
# Filter Complete
# Filter Complete
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (20.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (42.86%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (16.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (22.22%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (42.86%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (28.57%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (16.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (22.22%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (40.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (23.53%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# Filter Complete
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (40.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (23.53%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (40.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (23.53%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (40.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (23.53%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (40.00%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.67%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (23.53%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# Filter Complete
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.47%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (16.22%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.47%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (16.22%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (26.47%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.65%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (16.22%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.24%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (11.48%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (17.24%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.07%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (11.48%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (18.64%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (12.90%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (13.56%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# ...
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (15.13%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.43%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (15.13%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.43%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (15.13%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.43%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (15.13%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.88%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.43%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# Filter Complete
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (15.17%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.92%) exceeded threshold
#   warnings.warn("Fraction of excluded data "
# /home/ipsarros/more_venv2/lib/python3.8/site-packages/rdtools/normalization.py:727: UserWarning: Fraction of excluded data (10.48%) exceeded threshold
#   warnings.warn("Fraction of excluded data "

# %% [markdown]
# ### Plots

# %%
plt.figure(figsize=(14, 10))
derate_daily1 = pd.concat(derate_daily_pred_list1)
rmse1 = mse(gt_daily[derate_daily1.index], derate_daily1, squared=False)
derate_daily2 = pd.concat(derate_daily_pred_list2)
rmse2 = mse(gt_daily[derate_daily2.index], derate_daily2, squared=False)
derate_daily3 = pd.concat(derate_daily_pred_list3)
rmse3 = mse(gt_daily[derate_daily3.index], derate_daily3, squared=False)
derate_daily_srr = pd.concat(derate_daily_srr_list)
#rmse_srr = mse(gt_daily[derate_daily_srr.index], derate_daily_srr, squared=False)
#rmse_srr2 = mse(gt_daily[derate_daily1.index], derate_daily_srr[derate_daily1.index], squared=False)
#rmse_srr3 = mse(gt_daily[derate_daily2.index], derate_daily_srr[derate_daily2.index], squared=False)

plt.plot(derate_daily1, label = 'training after changepoints1')
plt.plot(derate_daily2, label = 'training after changepoints2')
plt.plot(derate_daily3, label = 'training after manual cleanings')
plt.plot(derate_daily_srr, alpha = 0.5, label = 'srr') #, label = 'rdtools-normalized')
plt.plot(gt_daily, color = 'goldenrod', label = 'groundtruth')
#         #plt.set_ylim(0.94,1.05)
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(16,14))
#plt.suptitle(f'Changepoint Detection Methods')
axes = axes.ravel()

ax2 = axes[0]
ax2.set_title('Model trained after manual cleanings')
ax2.plot(derate_daily2, label = 'modelled soiling ratio')
ax2.plot(gt_daily, color = 'goldenrod', label = 'soiling derate')
ax2.xaxis.set_visible(False)
ax2.legend()


ax1 = axes[1]
ax1.set_title('Model trained after cleaning events obtained by Method 1')
ax1.plot(derate_daily1, label = 'modelled soiling ratio')
ax1.plot(gt_daily, color = 'goldenrod', label = 'soiling derate')
ax1.xaxis.set_visible(False)
ax1.legend()

ax3 = axes[2]
ax3.set_title('Model trained after cleaning events obtained by Method 2')
ax3.plot(derate_daily3, label = 'modelled soiling ratio')
ax3.plot(gt_daily, color = 'goldenrod', label = 'soiling derate')
ax3.xaxis.set_visible(False)
ax3.legend()

ax4 = axes[3]
ax4.set_title('Performance Metric (SRR)')
ax4.plot(gt_daily, color = 'goldenrod', label = 'soiling derate')
ax4.plot(derate_daily_srr, color = 'black', alpha = 0.5, label = 'Perf. metric (SRR)')

ax4.legend()
plt.show()

# %%
new_index = derate_daily3.index.intersection(gt_daily.index)
new_index = derate_daily2.index.intersection(new_index)
new_index = derate_daily1.index.intersection(new_index)

# %%
derate_daily1 = derate_daily1[~derate_daily1.index.duplicated(keep='first')]
derate_daily2 = derate_daily2[~derate_daily2.index.duplicated(keep='first')]
derate_daily3 = derate_daily3[~derate_daily3.index.duplicated(keep='first')]

# %%
rmse1 = mse(gt_daily[new_index], derate_daily1[new_index], squared=False)
rmse2 = mse(gt_daily[new_index], derate_daily2[new_index], squared=False)
rmse3 = mse(gt_daily[new_index], derate_daily3[new_index], squared=False)
rmse_srr = mse(gt_daily[new_index], derate_daily_srr[new_index], squared=False)

# %%
#computed over maximal intervals of groundtruth
print(rmse1)
print(rmse2)
print(rmse3)
print(rmse_srr)
# Out:
# 0.014480190211650344
# 0.015816155305616537
# 0.01423502046456508
# 0.021712857243295178
